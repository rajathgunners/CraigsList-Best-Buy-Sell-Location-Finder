# %% [markdown]
# Scrape URL of CraigsList sites from different locations from https://geo.craigslist.org/iso/us and save it to  "CraigsListLinks.xlsx" to be used later for scraping the prices of searched product

# %%
import requests, json

from bs4 import BeautifulSoup

import pandas as pd

import os

import re

import time

API_KEY = os.environ["LOCATIONIQ_API_KEY"]

#Function to return geocoordinates of cities 
def FindLatLong(city):
    time.sleep(1)
    url = "https://us1.locationiq.com/v1/search.php"
    params = {
        'key': API_KEY,
        'q': city,
        'format': 'json',
        'limit' : 1,
        'countrycodes': 'us',
        }
    
    retries_count = 0
    
    while True: 
        response = json.loads(requests.get(url, params=params).text)
        if 'error' in response and retries_count < 1:
            params['q'] = re.sub('[^A-Za-z,]',' ',params['q'])
            retries_count +=1
        else:
            break
        
    
    if 'error' in response:
        geo_coord = {'lat': None, 'lon': None}
    else:
        geo_coord = {k : response[0][k] for k in ('lat', 'lon')}
    
    print(city , "  ", geo_coord)
    return geo_coord

# %%
site_resp = requests.get("https://geo.craigslist.org/iso/us")

site_soup = BeautifulSoup(site_resp.content, "html.parser")

#%%timeit
#pulling out craigslist links from the website
city_links_list = map(lambda x: (x.get_attribute_list('href')[0], x.text), site_soup.section.findAll('a')) 

#creating a dataframe with the city names and corresponding links
df_cities = pd.DataFrame(list(city_links_list), columns=['link', 'city'])

#fining latitude and longitude of cities using LocationIQ geocode services API and adding to dataframe for plotting on map
df_cities = df_cities.merge(df_cities.city.apply(lambda x: pd.Series(FindLatLong(x))), left_index=True, right_index=True)

writer = pd.ExcelWriter('Static/CraigsListLinks.xlsx')

df_cities.to_excel(writer, sheet_name="Links")

writer.save()

print("Excel File Created")
# Out:
# abilene, TX    {'lat': '32.4466741', 'lon': '-99.7333011'}
# akron / canton    {'lat': '41.042311', 'lon': '-81.436089'}
# albany, GA    {'lat': '31.5782062', 'lon': '-84.1556809'}
# albany, NY    {'lat': '42.6511674', 'lon': '-73.754968'}
# albuquerque    {'lat': '35.0841034', 'lon': '-106.6509851'}
# altoona-johnstown    {'lat': '40.449452', 'lon': '-78.39367'}
# amarillo, TX    {'lat': '35.2072185', 'lon': '-101.8338246'}
# ames, IA    {'lat': '42.0267703', 'lon': '-93.6170554'}
# anchorage / mat-su    {'lat': '61.58083935', 'lon': '-149.237775548072'}
# annapolis, MD    {'lat': '38.9786401', 'lon': '-76.492786'}
# ann arbor, MI    {'lat': '42.2681569', 'lon': '-83.7312291'}
# appleton-oshkosh-FDL    {'lat': '44.02541', 'lon': '-88.548962'}
# asheville, NC    {'lat': '35.6009498', 'lon': '-82.5540161'}
# ashtabula, OH    {'lat': '41.7167229', 'lon': '-80.74947'}
# athens, GA    {'lat': '33.9597677', 'lon': '-83.376398'}
# athens, OH    {'lat': '39.3289242', 'lon': '-82.1012479'}
# atlanta, GA    {'lat': '33.7490987', 'lon': '-84.3901849'}
# auburn, AL    {'lat': '32.6848205', 'lon': '-85.4882773112481'}
# augusta, GA    {'lat': '33.4709714', 'lon': '-81.9748429'}
# austin, TX    {'lat': '30.30758105', 'lon': '-97.712630246401'}
# bakersfield, CA    {'lat': '35.3738712', 'lon': '-119.0194639'}
# baltimore, MD    {'lat': '39.2908816', 'lon': '-76.610759'}
# baton rouge    {'lat': '30.4459596', 'lon': '-91.18738'}
# battle creek, MI    {'lat': '42.3192548', 'lon': '-85.1824269'}
# beaumont / port arthur    {'lat': '29.942133', 'lon': '-93.968942'}
# bellingham, WA    {'lat': '48.7544012', 'lon': '-122.4788361'}
# bemidji, MN    {'lat': '47.478654', 'lon': '-94.890802'}
# bend, OR    {'lat': '44.0581728', 'lon': '-121.3153096'}
# billings, MT    {'lat': '45.7874957', 'lon': '-108.49607'}
# binghamton, NY    {'lat': '42.096968', 'lon': '-75.914341'}
# birmingham, AL    {'lat': '33.5206824', 'lon': '-86.8024326'}
# bismarck, ND    {'lat': '46.808327', 'lon': '-100.783739'}
# bloomington, IN    {'lat': '39.1670396', 'lon': '-86.5342881'}
# bloomington-normal    {'lat': '40.4787086', 'lon': '-88.9236876'}
# boise, ID    {'lat': '43.61656', 'lon': '-116.200835'}
# boone, NC    {'lat': '36.216795', 'lon': '-81.6745517'}
# boston    {'lat': '42.3602534', 'lon': '-71.0582912'}
# boulder, CO    {'lat': '40.0149856', 'lon': '-105.2705456'}
# bowling green, KY    {'lat': '36.9903199', 'lon': '-86.4436018'}
# bozeman, MT    {'lat': '45.679984', 'lon': '-111.044675'}
# brainerd, MN    {'lat': '46.3580221', 'lon': '-94.2008288'}
# brownsville, TX    {'lat': '25.9140256', 'lon': '-97.4890856'}
# brunswick, GA    {'lat': '31.1499528', 'lon': '-81.4914894'}
# buffalo, NY    {'lat': '42.8867166', 'lon': '-78.8783922'}
# butte, MT    {'lat': '46.0131505', 'lon': '-112.5365089'}
# cape cod / islands    {'lat': '41.7117756', 'lon': '-70.3361342'}
# catskills    {'lat': '30.197119', 'lon': '-81.790825'}
# cedar rapids, IA    {'lat': '41.9758872', 'lon': '-91.6704053'}
# central louisiana    {'lat': '30.8703881', 'lon': '-92.007126'}
# central michigan    {'lat': '43.6211955', 'lon': '-84.6824346'}
# central NJ    {'lat': '40.0757384', 'lon': '-74.4041622'}
# champaign urbana    {'lat': '40.1117174', 'lon': '-88.207301'}
# charleston, SC    {'lat': '32.7876012', 'lon': '-79.9402728'}
# charleston, WV    {'lat': '38.3505995', 'lon': '-81.6332812'}
# charlotte, NC    {'lat': '35.2270869', 'lon': '-80.8431268'}
# charlottesville, VA    {'lat': '38.029306', 'lon': '-78.4766781'}
# chattanooga, TN    {'lat': '35.0456297', 'lon': '-85.3096801'}
# chautauqua, NY    {'lat': '42.2894671', 'lon': '-79.421728'}
# chicago    {'lat': '41.8755616', 'lon': '-87.6244212'}
# chico, CA    {'lat': '39.7284945', 'lon': '-121.8374777'}
# chillicothe, OH    {'lat': '39.3331197', 'lon': '-82.9824019'}
# cincinnati, OH    {'lat': '39.1014537', 'lon': '-84.5124602'}
# clarksville, TN    {'lat': '36.5277607', 'lon': '-87.3588703'}
# cleveland, OH    {'lat': '41.5051613', 'lon': '-81.6934446'}
# clovis / portales    {'lat': '34.2443264', 'lon': '-103.259869'}
# college station, TX    {'lat': '30.6001408', 'lon': '-96.3101229'}
# colorado springs    {'lat': '38.8339578', 'lon': '-104.8253485'}
# columbia / jeff city    {'lat': '38.653359', 'lon': '-90.2190933233186'}
# columbia, SC    {'lat': '34.0007493', 'lon': '-81.0343313'}
# columbus, GA    {'lat': '32.4609764', 'lon': '-84.9877094'}
# columbus, OH    {'lat': '39.9622601', 'lon': '-83.0007065'}
# cookeville, TN    {'lat': '36.1623886', 'lon': '-85.4997057'}
# corpus christi, TX    {'lat': '27.8002542', 'lon': '-97.3955744'}
# corvallis/albany    {'lat': '44.6308249', 'lon': '-123.1020937'}
# cumberland valley    {'lat': '39.2744299', 'lon': '-88.2423795'}
# dallas / fort worth    {'lat': '32.5854135', 'lon': '-96.9686156'}
# danville    {'lat': '40.125222', 'lon': '-87.6304614'}
# daytona beach    {'lat': '29.2108147', 'lon': '-81.0228331'}
# dayton / springfield    {'lat': '39.778021', 'lon': '-84.13956'}
# decatur, IL    {'lat': '39.8454163', 'lon': '-88.9524151'}
# deep east texas    {'lat': '29.5895841', 'lon': '-95.1191868'}
# delaware    {'lat': '38.6920451', 'lon': '-75.4013315'}
# del rio / eagle pass    {'lat': '28.7091433', 'lon': '-100.4995214'}
# denver, CO    {'lat': '39.7392364', 'lon': '-104.9848623'}
# des moines, IA    {'lat': '41.5910641', 'lon': '-93.6037149'}
# detroit metro    {'lat': '42.4155001', 'lon': '-83.0310085077022'}
# dothan, AL    {'lat': '31.2232313', 'lon': '-85.3904889'}
# dubuque    {'lat': '42.502247', 'lon': '-90.692006'}
# duluth / superior    {'lat': '46.78110995', 'lon': '-92.1043262400139'}
# eastern CO    {'lat': '40.4970088', 'lon': '-80.8959208'}
# eastern CT    {'lat': '39.5059043', 'lon': '-76.1800651'}
# eastern kentucky    {'lat': '37.5170432', 'lon': '-82.805994'}
# eastern montana    {'lat': '46.3811136', 'lon': '-105.824847797988'}
# eastern NC    {'lat': '33.9201654', 'lon': '-78.2342767'}
# eastern panhandle    {'lat': '39.5733818', 'lon': '-89.9867748'}
# eastern shore    {'lat': '39.6031', 'lon': '-76.0671'}
# east idaho    {'lat': '48.2691331', 'lon': '-116.5471244'}
# east oregon    {'lat': '43.9792797', 'lon': '-120.737257'}
# eau claire, WI    {'lat': '44.811349', 'lon': '-91.4984941'}
# elko, NV    {'lat': '40.8324188', 'lon': '-115.7630982'}
# elmira-corning    {'lat': '42.1608441', 'lon': '-76.8919903845347'}
# el paso, TX    {'lat': '31.7600372', 'lon': '-106.487287'}
# erie, PA    {'lat': '42.1294712', 'lon': '-80.0852695'}
# eugene, OR    {'lat': '44.0505054', 'lon': '-123.0950506'}
# evansville, IN    {'lat': '37.9747645', 'lon': '-87.5558483'}
# fairbanks, AK    {'lat': '64.837845', 'lon': '-147.716675'}
# fargo / moorhead    {'lat': '46.8907935', 'lon': '-96.7710792'}
# farmington, NM    {'lat': '36.7304288', 'lon': '-108.2089191'}
# fayetteville, AR    {'lat': '36.0625843', 'lon': '-94.1574328'}
# fayetteville, NC    {'lat': '35.0525759', 'lon': '-78.878292'}
# finger lakes, NY    {'lat': '42.5106272', 'lon': '-76.7896763'}
# flagstaff / sedona    {'lat': '29.4836331', 'lon': '-95.1147583'}
# flint, MI    {'lat': '43.0171773', 'lon': '-83.7236024'}
# florence / muscle shoals    {'lat': '34.7576619', 'lon': '-87.6665591'}
# florence, SC    {'lat': '34.1984435', 'lon': '-79.7671658'}
# florida keys    {'lat': '24.6670875', 'lon': '-81.5831421'}
# fort collins / north CO    {'lat': '40.5508527', 'lon': '-105.0668085'}
# fort dodge, IA    {'lat': '42.4974694', 'lon': '-94.1680158'}
# fort smith, AR    {'lat': '35.3872218', 'lon': '-94.4248983'}
# fort wayne, IN    {'lat': '41.0799898', 'lon': '-85.1386015'}
# frederick, MD    {'lat': '39.4142186', 'lon': '-77.4109269'}
# fredericksburg, VA    {'lat': '38.3031837', 'lon': '-77.4605399'}
# fresno / madera    {'lat': '37.2014167', 'lon': '-119.8015057'}
# ft myers / SW florida    {'lat': '26.640628', 'lon': '-81.8723084'}
# gadsden-anniston    {'lat': '33.706305', 'lon': '-85.858638'}
# gainesville, FL    {'lat': '29.6519396', 'lon': '-82.3249961'}
# galveston, TX    {'lat': '29.299328', 'lon': '-94.7945882'}
# glens falls, NY    {'lat': '43.309941', 'lon': '-73.644447'}
# gold country    {'lat': '38.89101', 'lon': '-121.0746678'}
# grand forks    {'lat': '47.9078244', 'lon': '-97.0592028'}
# grand island, NE    {'lat': '40.924271', 'lon': '-98.338685'}
# grand rapids, MI    {'lat': '42.9632405', 'lon': '-85.6678639'}
# great falls, MT    {'lat': '47.5048851', 'lon': '-111.2918908'}
# green bay, WI    {'lat': '44.5126379', 'lon': '-88.0125794'}
# greensboro, NC    {'lat': '36.0726355', 'lon': '-79.7919754'}
# greenville / upstate    {'lat': '34.78831435', 'lon': '-82.3847959534128'}
# gulfport / biloxi    {'lat': '29.421171', 'lon': '-94.69148'}
# hanford-corcoran    {'lat': '60.707779', 'lon': '-151.347835'}
# harrisburg, PA    {'lat': '40.2663107', 'lon': '-76.8861122'}
# harrisonburg, VA    {'lat': '38.4493315', 'lon': '-78.8688833'}
# hartford, CT    {'lat': '41.764582', 'lon': '-72.6908547'}
# hattiesburg, MS    {'lat': '31.3271189', 'lon': '-89.2903392'}
# hawaii    {'lat': '21.2160437', 'lon': '-157.975203'}
# heartland florida    {'lat': '26.39543145', 'lon': '-80.0873776748035'}
# helena, MT    {'lat': '46.592712', 'lon': '-112.036109'}
# hickory / lenoir    {'lat': '35.287663', 'lon': '-77.6541388'}
# high rockies    {'lat': '34.00327', 'lon': '-118.236458'}
# hilton head    {'lat': '32.1618488', 'lon': '-80.7512616'}
# holland, MI    {'lat': '42.7876022', 'lon': '-86.1090828'}
# houma, LA    {'lat': '29.5957696', 'lon': '-90.7195348'}
# houston, TX    {'lat': '29.7589382', 'lon': '-95.3676974'}
# hudson valley, NY    {'lat': '41.31611085', 'lon': '-74.1262918922516'}
# humboldt county    {'lat': '40.5997415', 'lon': '-123.8997734'}
# huntington-ashland    {'lat': '41.116348', 'lon': '-82.219726'}
# huntsville / decatur    {'lat': '34.635331', 'lon': '-87.0556185'}
# imperial county    {'lat': '33.0305487', 'lon': '-115.3595666'}
# indianapolis    {'lat': '39.7683331', 'lon': '-86.1583502'}
# inland empire, CA    {'lat': '37.648393', 'lon': '-120.900773'}
# iowa city, IA    {'lat': '41.6612561', 'lon': '-91.5299106'}
# ithaca, NY    {'lat': '42.4396039', 'lon': '-76.4968019'}
# jackson, MI    {'lat': '32.2990384', 'lon': '-90.1847691'}
# jackson, MS    {'lat': '32.2990384', 'lon': '-90.1847691'}
# jackson, TN    {'lat': '35.6144446', 'lon': '-88.8177418'}
# jacksonville, FL    {'lat': '30.3321838', 'lon': '-81.655651'}
# jacksonville, NC    {'lat': '34.7540524', 'lon': '-77.4302415'}
# janesville, WI    {'lat': '42.6829765', 'lon': '-89.0226793'}
# jersey shore    {'lat': '41.2020171', 'lon': '-77.2644152'}
# jonesboro, AR    {'lat': '35.8428646', 'lon': '-90.7034522'}
# joplin, MO    {'lat': '37.08418', 'lon': '-94.51323'}
# kalamazoo, MI    {'lat': '42.291707', 'lon': '-85.5872286'}
# kalispell, MT    {'lat': '48.2022563', 'lon': '-114.3167117'}
# kansas city, MO    {'lat': '39.100105', 'lon': '-94.5781416'}
# kenai peninsula    {'lat': '60.0968272', 'lon': '-151.788033'}
# kennewick-pasco-richland    {'lat': '46.2394161', 'lon': '-119.245748'}
# kenosha-racine    {'lat': '42.74803105', 'lon': '-87.7856676460861'}
# killeen / temple / ft hood    {'lat': '31.09237', 'lon': '-97.72734'}
# kirksville, MO    {'lat': '40.1948848', 'lon': '-92.5833939'}
# klamath falls, OR    {'lat': '42.224867', 'lon': '-121.7816704'}
# knoxville, TN    {'lat': '35.9603948', 'lon': '-83.9210261'}
# kokomo, IN    {'lat': '40.4864444', 'lon': '-86.1336351'}
# la crosse, WI    {'lat': '43.8014053', 'lon': '-91.2395429'}
# lafayette, LA    {'lat': '30.2240897', 'lon': '-92.0198427'}
# lafayette / west lafayette    {'lat': '42.33998705', 'lon': '-83.0337494838953'}
# lake charles, LA    {'lat': '30.2265949', 'lon': '-93.2173759'}
# lakeland, FL    {'lat': '28.0394654', 'lon': '-81.9498042'}
# lake of the ozarks    {'lat': '38.2035967', 'lon': '-92.6266766'}
# lancaster, PA    {'lat': '40.03813', 'lon': '-76.3056686'}
# lansing, MI    {'lat': '42.7337712', 'lon': '-84.5553805'}
# laredo, TX    {'lat': '27.5199841', 'lon': '-99.4953764'}
# la salle co    {'lat': '28.3391148', 'lon': '-99.0982257'}
# las cruces, NM    {'lat': '32.3140354', 'lon': '-106.7798078'}
# las vegas    {'lat': '36.1674185', 'lon': '-115.1485573'}
# lawrence, KS    {'lat': '38.9719384', 'lon': '-95.2359496'}
# lawton, OK    {'lat': '34.6086854', 'lon': '-98.3903305'}
# lehigh valley    {'lat': '40.5947107', 'lon': '-75.5679786'}
# lewiston / clarkston    {'lat': '41.9313155', 'lon': '-111.9146716'}
# lexington, KY    {'lat': '38.0464066', 'lon': '-84.4970393'}
# lima / findlay    {'lat': '41.0116987', 'lon': '-83.6810464767326'}
# lincoln, NE    {'lat': '40.8', 'lon': '-96.667821'}
# little rock    {'lat': '34.7464809', 'lon': '-92.2895948'}
# logan, UT    {'lat': '41.7313447', 'lon': '-111.8348631'}
# long island, NY    {'lat': '43.1520122', 'lon': '-76.0610324'}
# los angeles    {'lat': '34.0536834', 'lon': '-118.2427669'}
# louisville, KY    {'lat': '38.2542376', 'lon': '-85.759407'}
# lubbock, TX    {'lat': '33.5778631', 'lon': '-101.8551665'}
# lynchburg, VA    {'lat': '37.40088', 'lon': '-79.1844923945909'}
# macon / warner robins    {'lat': '32.6146047', 'lon': '-83.6862002'}
# madison, WI    {'lat': '43.074761', 'lon': '-89.3837613'}
# maine    {'lat': '45.709097', 'lon': '-68.8590201'}
# manhattan, KS    {'lat': '39.1836082', 'lon': '-96.5716694'}
# mankato, MN    {'lat': '44.1634663', 'lon': '-93.9993505'}
# mansfield, OH    {'lat': '40.75839', 'lon': '-82.5154471'}
# mason city, IA    {'lat': '43.1535728', 'lon': '-93.2010367'}
# mattoon-charleston    {'lat': '39.4797189', 'lon': '-88.3215233'}
# mcallen / edinburg    {'lat': '26.1552479', 'lon': '-98.2476596'}
# meadville, PA    {'lat': '41.641445', 'lon': '-80.151449'}
# medford-ashland    {'lat': '42.420156', 'lon': '-71.107384'}
# memphis, TN    {'lat': '35.1490215', 'lon': '-90.0516285'}
# mendocino county    {'lat': '39.3176491', 'lon': '-123.4126399'}
# merced, CA    {'lat': '37.3029568', 'lon': '-120.4843269'}
# meridian, MS    {'lat': '32.3643098', 'lon': '-88.703656'}
# milwaukee, WI    {'lat': '43.0349931', 'lon': '-87.922497'}
# minneapolis / st paul    {'lat': '44.07517895', 'lon': '-95.6656745942574'}
# missoula, MT    {'lat': '46.8700801', 'lon': '-113.9952796'}
# mobile, AL    {'lat': '30.6943566', 'lon': '-88.0430541'}
# modesto, CA    {'lat': '37.6390972', 'lon': '-120.9968782'}
# mohave county    {'lat': '35.7218038', 'lon': '-113.8271174'}
# monroe, LA    {'lat': '32.5093109', 'lon': '-92.1193012'}
# monroe, MI    {'lat': '41.9145037', 'lon': '-83.3968252'}
# monterey bay    {'lat': '36.7999557', 'lon': '-121.9010668'}
# montgomery, AL    {'lat': '32.3669656', 'lon': '-86.3006485'}
# morgantown, WV    {'lat': '39.6296809', 'lon': '-79.9559437'}
# moses lake, WA    {'lat': '47.1301417', 'lon': '-119.2780771'}
# muncie / anderson    {'lat': '34.481295', 'lon': '-82.640648'}
# muskegon, MI    {'lat': '43.2341813', 'lon': '-86.2483921'}
# myrtle beach, SC    {'lat': '33.6956461', 'lon': '-78.8900409'}
# nashville, TN    {'lat': '36.1622296', 'lon': '-86.7743531'}
# new hampshire    {'lat': '43.4849133', 'lon': '-71.6553992'}
# new haven, CT    {'lat': '41.3082138', 'lon': '-72.9250518'}
# new orleans    {'lat': '29.9499323', 'lon': '-90.0701156'}
# new river valley    {'lat': '37.7301385', 'lon': '-80.9057796'}
# new york city    {'lat': '40.7308619', 'lon': '-73.9871558'}
# norfolk / hampton roads    {'lat': '36.8479165', 'lon': '-76.2902105'}
# north central FL    {'lat': '38.09979', 'lon': '-86.15858'}
# north dakota    {'lat': '47.6201461', 'lon': '-100.540737'}
# northeast SD    {'lat': '44.6471761', 'lon': '-100.348761'}
# northern michigan    {'lat': '43.7500661', 'lon': '-85.1447326'}
# northern panhandle    {'lat': '39.64202', 'lon': '-80.85649'}
# northern WI    {'lat': '45.83804', 'lon': '-89.4876243429532'}
# north jersey    {'lat': '39.0848464', 'lon': '-90.3303344'}
# north mississippi    {'lat': '32.9715645', 'lon': '-89.7348497'}
# north platte, NE    {'lat': '41.1238873', 'lon': '-100.7654232'}
# northwest CT    {'lat': '42.36153215', 'lon': '-71.089321565066'}
# northwest GA    {'lat': '39.25679175', 'lon': '-84.5898822999136'}
# northwest KS    {'lat': '38.27312', 'lon': '-98.5821872'}
# northwest OK    {'lat': '40.94693265', 'lon': '-72.842674652717'}
# ocala, FL    {'lat': '29.1871986', 'lon': '-82.1400923'}
# odessa / midland    {'lat': '31.8870229', 'lon': '-102.257262614127'}
# ogden-clearfield    {'lat': '41.007265', 'lon': '-78.429117'}
# okaloosa / walton    {'lat': '30.4057552', 'lon': '-86.618842'}
# oklahoma city    {'lat': '35.4729886', 'lon': '-97.5170536'}
# olympic peninsula    {'lat': '48.0827524', 'lon': '-123.08469037704'}
# omaha / council bluffs    {'lat': '41.2621283', 'lon': '-95.8613912'}
# oneonta, NY    {'lat': '42.453492', 'lon': '-75.0629531'}
# orange county, CA    {'lat': '33.7500378', 'lon': '-117.8704931'}
# oregon coast    {'lat': '45.9858973', 'lon': '-123.922357303404'}
# orlando, FL    {'lat': '28.5421097', 'lon': '-81.3790388'}
# outer banks    {'lat': '35.5668467', 'lon': '-75.4684908'}
# owensboro, KY    {'lat': '37.7742152', 'lon': '-87.1133304'}
# palm springs, CA    {'lat': '33.77217945', 'lon': '-116.495297697851'}
# panama city, FL    {'lat': '30.1600827', 'lon': '-85.6545729'}
# parkersburg-marietta    {'lat': '39.2635223', 'lon': '-81.556547'}
# pensacola, FL    {'lat': '30.421309', 'lon': '-87.2169149'}
# peoria, IL    {'lat': '40.6938609', 'lon': '-89.5891008'}
# philadelphia    {'lat': '39.9524152', 'lon': '-75.1635755'}
# phoenix, AZ    {'lat': '33.4485866', 'lon': '-112.0773456'}
# pierre / central SD    {'lat': '44.368305', 'lon': '-100.351185'}
# pittsburgh, PA    {'lat': '40.4416941', 'lon': '-79.9900861'}
# plattsburgh-adirondacks    {'lat': '44.693302', 'lon': '-73.466425'}
# poconos    {'lat': '41.0256428', 'lon': '-75.6046334'}
# port huron, MI    {'lat': '42.9815877', 'lon': '-82.440466'}
# portland, OR    {'lat': '45.5202471', 'lon': '-122.6741949'}
# potsdam-canton-massena    {'lat': '44.677041', 'lon': '-74.982067'}
# prescott, AZ    {'lat': '34.5402813', 'lon': '-112.469518'}
# provo / orem    {'lat': '40.3152147', 'lon': '-111.6537888'}
# pueblo, CO    {'lat': '38.2544472', 'lon': '-104.609141'}
# pullman / moscow    {'lat': '46.74430515', 'lon': '-117.110283678028'}
# quad cities, IA/IL    {'lat': '41.5579867', 'lon': '-90.520986'}
# raleigh / durham / CH    {'lat': '35.8930642', 'lon': '-78.8489052811966'}
# rapid city / west SD    {'lat': '44.081176', 'lon': '-103.228006'}
# reading, PA    {'lat': '40.335345', 'lon': '-75.9279495'}
# redding, CA    {'lat': '40.5863563', 'lon': '-122.3916754'}
# reno / tahoe    {'lat': '39.4986462', 'lon': '-119.773331865361'}
# rhode island    {'lat': '41.7962409', 'lon': '-71.5992372'}
# richmond, IN    {'lat': '39.8286897', 'lon': '-84.8898521'}
# richmond, VA    {'lat': '37.5385087', 'lon': '-77.43428'}
# roanoke, VA    {'lat': '37.274532', 'lon': '-79.9602096795782'}
# rochester, MN    {'lat': '44.0234387', 'lon': '-92.4630182'}
# rochester, NY    {'lat': '43.157285', 'lon': '-77.615214'}
# rockford, IL    {'lat': '42.2713945', 'lon': '-89.093966'}
# roseburg, OR    {'lat': '43.216505', 'lon': '-123.3417381'}
# roswell / carlsbad    {'lat': '33.587066', 'lon': '-104.511508'}
# sacramento    {'lat': '38.5815719', 'lon': '-121.4943996'}
# saginaw-midland-baycity    {'lat': '43.53149', 'lon': '-84.08738'}
# salem, OR    {'lat': '44.9391565', 'lon': '-123.033121'}
# salina, KS    {'lat': '38.8402805', 'lon': '-97.6114237'}
# salt lake city    {'lat': '40.7670126', 'lon': '-111.8904308'}
# san angelo, TX    {'lat': '31.4648357', 'lon': '-100.4398442'}
# san antonio    {'lat': '29.4246002', 'lon': '-98.4951405'}
# san diego    {'lat': '32.7174209', 'lon': '-117.1627714'}
# sandusky, OH    {'lat': '41.4489397', 'lon': '-82.7079605'}
# san luis obispo    {'lat': '35.2827525', 'lon': '-120.6596156'}
# san marcos, TX    {'lat': '29.8826436', 'lon': '-97.9405828'}
# santa barbara    {'lat': '34.4221319', 'lon': '-119.7026673'}
# santa fe / taos    {'lat': '29.4366242', 'lon': '-98.6701153'}
# santa maria, CA    {'lat': '34.9531295', 'lon': '-120.4358577'}
# sarasota-bradenton    {'lat': '27.39598835', 'lon': '-82.5540742306453'}
# savannah / hinesville    {'lat': '31.7884104', 'lon': '-81.6357479'}
# scottsbluff / panhandle    {'lat': '41.887668', 'lon': '-103.6697292'}
# scranton / wilkes-barre    {'lat': '41.33713525', 'lon': '-75.7225490617848'}
# seattle-tacoma    {'lat': '47.4475673', 'lon': '-122.308015856951'}
# SF bay area    {'lat': '37.7884969', 'lon': '-122.3558473'}
# sheboygan, WI    {'lat': '43.7508284', 'lon': '-87.71453'}
# show low, AZ    {'lat': '34.2542084', 'lon': '-110.0298327'}
# shreveport, LA    {'lat': '32.5221828', 'lon': '-93.7651944'}
# sierra vista, AZ    {'lat': '31.5545401', 'lon': '-110.3036929'}
# sioux city, IA    {'lat': '42.4966815', 'lon': '-96.4058782'}
# sioux falls / SE SD    {'lat': '43.5499749', 'lon': '-96.700327'}
# siskiyou county    {'lat': '41.5007223', 'lon': '-122.544354147521'}
# skagit / island / SJI    {'lat': '48.476299', 'lon': '-122.334'}
# south bend / michiana    {'lat': '41.72347405', 'lon': '-86.2881080721099'}
# south coast, MA    {'lat': '32.7469891', 'lon': '-117.2516124'}
# south dakota    {'lat': '44.6471761', 'lon': '-100.348761'}
# southeast alaska    {'lat': '64.4459613', 'lon': '-149.680909'}
# southeast IA    {'lat': '41.9216734', 'lon': '-93.3122705'}
# southeast KS    {'lat': '38.27312', 'lon': '-98.5821872'}
# southeast missouri    {'lat': '38.7604815', 'lon': '-92.5617875'}
# southern illinois    {'lat': '38.7931034', 'lon': '-89.9942698'}
# southern maryland    {'lat': '30.5236116', 'lon': '-91.1946063'}
# southern WV    {'lat': '37.8463451', 'lon': '-81.9917984'}
# south florida    {'lat': '37.1677128', 'lon': '-94.8464256'}
# south jersey    {'lat': '39.0848464', 'lon': '-90.3303344'}
# southwest KS    {'lat': '38.27312', 'lon': '-98.5821872'}
# southwest michigan    {'lat': '43.6211955', 'lon': '-84.6824346'}
# southwest MN    {'lat': '44.9139652', 'lon': '-93.3001503'}
# southwest MS    {'lat': '35.10742345', 'lon': '-80.9927464290993'}
# southwest TX    {'lat': '31.8160381', 'lon': '-99.5120986'}
# southwest VA    {'lat': '38.87307725', 'lon': '-77.1547548074723'}
# space coast, FL    {'lat': '29.55418705', 'lon': '-81.2351269814777'}
# spokane / coeur d'alene    {'lat': '47.687039', 'lon': '-116.767646'}
# springfield, IL    {'lat': '39.7990175', 'lon': '-89.6439575'}
# springfield, MO    {'lat': '37.2166779', 'lon': '-93.2920373'}
# state college, PA    {'lat': '40.7944504', 'lon': '-77.8616386'}
# statesboro, GA    {'lat': '32.4490141', 'lon': '-81.7832912'}
# st augustine, FL    {'lat': '29.8946952', 'lon': '-81.3145395'}
# st cloud, MN    {'lat': '45.5616075', 'lon': '-94.1642004'}
# st george, UT    {'lat': '37.104153', 'lon': '-113.5841313'}
# stillwater, OK    {'lat': '36.1156306', 'lon': '-97.0585717'}
# st joseph    {'lat': '39.765686', 'lon': '-94.814655'}
# st louis, MO    {'lat': '38.6272733', 'lon': '-90.1978889'}
# stockton, CA    {'lat': '37.9577016', 'lon': '-121.2907796'}
# susanville, CA    {'lat': '40.4162842', 'lon': '-120.6530063'}
# syracuse, NY    {'lat': '43.0481221', 'lon': '-76.1474244'}
# tallahassee    {'lat': '30.4380832', 'lon': '-84.2809332'}
# tampa bay area    {'lat': '27.8801235', 'lon': '-82.3466538315203'}
# terre haute, IN    {'lat': '39.4667025', 'lon': '-87.4139119'}
# texarkana    {'lat': '33.4254684', 'lon': '-94.0430977'}
# texoma    {'lat': '33.95505255', 'lon': '-96.9571172432033'}
# the thumb, MI    {'lat': '35.2041478', 'lon': '-106.4540884'}
# toledo, OH    {'lat': '41.6786754', 'lon': '-83.5127283'}
# topeka, KS    {'lat': '39.049011', 'lon': '-95.677556'}
# treasure coast, FL    {'lat': '27.4518379', 'lon': '-80.421173'}
# tri-cities, TN    {'lat': '46.26395235', 'lon': '-119.113036872055'}
# tucson, AZ    {'lat': '32.2218917', 'lon': '-110.9262353'}
# tulsa, OK    {'lat': '36.1556805', 'lon': '-95.9929113'}
# tuscaloosa    {'lat': '33.2668398', 'lon': '-87.4862182'}
# tuscarawas co    {'lat': '40.3759469', 'lon': '-81.464888'}
# twin falls, ID    {'lat': '42.5704219', 'lon': '-114.4603171'}
# twin tiers NY/PA    {'lat': '42.120839', 'lon': '-77.946597'}
# tyler / east TX    {'lat': '30.7563939', 'lon': '-94.3984613'}
# upper peninsula, MI    {'lat': '46.5436104', 'lon': '-87.3962884'}
# utica-rome-oneida    {'lat': '43.07816205', 'lon': '-75.5147867816779'}
# valdosta, GA    {'lat': '30.8327022', 'lon': '-83.2784851'}
# ventura county    {'lat': '34.4458248', 'lon': '-119.0779359'}
# vermont    {'lat': '44.5990718', 'lon': '-72.5002608'}
# victoria, TX    {'lat': '28.8052674', 'lon': '-97.0035982'}
# visalia-tulare    {'lat': '36.3302284', 'lon': '-119.2920585'}
# waco, TX    {'lat': '31.549333', 'lon': '-97.1466695'}
# washington, DC    {'lat': '38.8950712', 'lon': '-77.0362758'}
# waterloo / cedar falls    {'lat': '42.5253897', 'lon': '-92.4413839'}
# watertown, NY    {'lat': '43.9747838', 'lon': '-75.9107565'}
# wausau, WI    {'lat': '44.9596017', 'lon': '-89.6298239'}
# wenatchee, WA    {'lat': '47.4234599', 'lon': '-120.3103494'}
# western IL    {'lat': '46.1519043', 'lon': '-96.1831165'}
# western KY    {'lat': '38.0529974', 'lon': '-84.5027598'}
# western maryland    {'lat': '38.0729013', 'lon': '-76.0232687'}
# western massachusetts    {'lat': '42.6457352', 'lon': '-71.3173401'}
# western slope    {'lat': '41.987711', 'lon': '-87.9319344312381'}
# west virginia (old)    {'lat': '38.4758406', 'lon': '-80.8408415'}
# wichita falls, TX    {'lat': '33.9137085', 'lon': '-98.4933873'}
# wichita, KS    {'lat': '37.6922361', 'lon': '-97.3375448'}
# williamsport, PA    {'lat': '41.2493292', 'lon': '-77.0027671'}
# wilmington, NC    {'lat': '34.2257282', 'lon': '-77.9447107'}
# winchester, VA    {'lat': '39.1852184', 'lon': '-78.1652404'}
# winston-salem, NC    {'lat': '36.0998131', 'lon': '-80.2440518'}
# worcester / central MA    {'lat': '42.2625932', 'lon': '-71.8022934'}
# wyoming    {'lat': '43.1700264', 'lon': '-107.5685348'}
# yakima, WA    {'lat': '46.601557', 'lon': '-120.5108421'}
# york, PA    {'lat': '39.962398', 'lon': '-76.727392'}
# youngstown, OH    {'lat': '41.1035786', 'lon': '-80.6520161'}
# yuba-sutter, CA    {'lat': '38.9076407', 'lon': '-121.5455588'}
# yuma, AZ    {'lat': '32.7253249', 'lon': '-114.624397'}
# zanesville / cambridge    {'lat': '39.9701058', 'lon': '-82.0097672'}
# Excel File Created
